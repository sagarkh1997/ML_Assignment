# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarkh1997/ML_Assignment/blob/main/pa5/PA5_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programming Assignment 5 - Build your own Conventional Neural Network
#
# After completing this project, you will be able to do the following:
#
# - Build neural network conveniently.
# - Configure with different regularization methods: Dropout, l1 or l2 regulation.
#
# - **574 Only**: Fine tune pre-trained model to build your own projects.
#
# # Dataset
#
# This dataset is provided by our current research project, which utilize 20 kHz acoustic sensing to sense ASL gestures. All the 10 ASL words perform by 5 subjects. All images are generated by using the short-time Fourier transform (STFT) to calculate a spectrogram as the feature representation of the reflected near-ultrasound waves. Based on the Doppler effect, sign language gestures, including both hands and arms, will cause phase and frequency changes of the reflected sonic wave. The spectrogram contains information in both frequency and time domains. The spectrogram is also defined as the Power Spectral Density of the function:
# \begin{equation}
#     \textrm{spectrogram}\{x(t)\}(\tau,\omega)\equiv |X(\tau,\omega)|^{2}= \left| \sum^{\infty}_{n=-\infty}x[n]\omega[n-m]e^{-j\omega n}\right|^{2}
# \end{equation}
# where $x[n]$ is input signal, and $\omega[n-m]$ represents the overlapping Kaiser window function with an adjustable shape factor $\beta$ that improves the resolution and reduces the spectral leakage close to the sidelobes of the signal. The coefficients of the Kaiser window are computed as:
# \begin{equation}
#     \omega[n]=\frac{I_{0}\left(\beta\sqrt{1-\left(\frac{n-N/2}{N/2}\right)^{2}}\right)}{I_{0}(\beta)}, 0 \leq n \leq N
# \end{equation}
#
# This dataset has a training set of 5,000 examples, and a test set of 1,000 examples.
#
# # Submission
#
# 1. **Coding checks (60 points)** - The code for your implementation should be in Python only. The name of the Main file should be main.ipynb or main.py. Please provide necessary comments in the code.
#
# 2. **Written Report (40 points)**: The report should be delivered as a separate pdf file, and it is recommended for you to use the NIPS template to structure your report. You may include comments in the Jupyter Notebook, however you will need to duplicate the results in the report. The report should describe your results, experimental setup and comparison between the results obtained
# from different setting of the algorithm and dataset.**Again, the questions in the Assignment PDF and here are the same (for the written report), we just put them in both places for convenience.**
#
#
# As such, you will submit, one member of your group will subit as a zip file on UBLearns, a ```.zip``` file that contains 3 things:
# - Your completed jupyter notebook.
# - Your written report.

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import regularizers
import zipfile
from tensorflow.keras.applications.resnet50 import ResNet50
import os
## please add the essential libraries
os.chdir('/content/')
with zipfile.ZipFile('pictures.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')
# os.chdir('pictures')

# %% [markdown]
# ## Part 1. loading dataset
#
# We have splitted the dataset into training, validation and test. You can load every single folder to load dataset using keras ImageDataGenerator (10 points).

# %%
# load the file from our dataset including training, validation and testing part
img_width, img_height = 224, 224
train_data_dir      = 'pictures/train'
validation_data_dir = 'pictures/val'
test_data_dir       = 'pictures/test'

epochs = 50
batch_size = 16

# # this is a generator that will read pictures found in
# # subfolers of 'data/train', and indefinitely generate
# # batches of augmented image data
datagen = ImageDataGenerator(rescale=1./255)

# Your Code HERE
train_generator = datagen.flow_from_directory(train_data_dir,target_size=(img_width,img_height),batch_size=batch_size)
valid_generator = datagen.flow_from_directory(validation_data_dir,target_size=(img_width,img_height),batch_size=batch_size)
test_generator  = datagen.flow_from_directory(test_data_dir,target_size=(img_width,img_height),batch_size=batch_size)


# please print the number of samples in each folder 
# Your Code HERE
# Out:
# Found 4176 images belonging to 10 classes.
# Found 1392 images belonging to 10 classes.
# Found 1392 images belonging to 10 classes.

# %% [markdown]
# ## Part 2.1 - Build your Neural Network and Train
#
# Build a Convolutional Neural Network with 2 or 3 hidden layers without regularization methods, which includes Conv2D layer, activation Layer. please use training dataset and validation dataset for training processs, and plot the training process with Loss trend and accuracy trend (30 Points).
#
# ## Part 2.2 - Test
#
# Test your machine learning model on the testing set: After finishing all the above steps, fix your hyper-parameters(learning rate, number of neurons per layer) and model parameter and test your model’s performance on the testing set. This shows the effectiveness of your model’s generalization power gained by learning. For test dataset, the performance should be more than 80% (10 Points).

# %%
# build conv2D CNN model, be careful with softmax and output layers is 10

# define the input shape of Convolutional Neural Network
# Your Code HERE
input_shape = (224,224,3) 

# define the Convolutional Neural Network
model = Sequential()
model.add(Conv2D(32, (3, 3),input_shape=(224,224,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(64, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Flatten())
# model.add(Dense(64))
# model.add(Activation('relu'))
model.add(Dense(10))
model.add(Activation('softmax'))

# Your Code HERE

# %%
# Compiling the model and training including the files of compile and fit
#Your code 
#Trying to remove error using custom loss function
model.compile(optimizer='adam',
              loss= 'categorical_crossentropy',
              metrics=['accuracy'])

#Train the model with training and validation set
model_normal = model.fit(train_generator,steps_per_epoch=len(train_generator),epochs=epochs,validation_data=valid_generator,validation_steps=len(valid_generator))
model.save_weights('first_try.h5')
# Out:
# Epoch 1/50
# 261/261 [==============================] - 19s 72ms/step - loss: 0.7090 - accuracy: 0.7577 - val_loss: 0.6347 - val_accuracy: 0.8628
# Epoch 2/50
# 261/261 [==============================] - 19s 72ms/step - loss: 0.0487 - accuracy: 0.9878 - val_loss: 0.8202 - val_accuracy: 0.8714
# Epoch 3/50
# 261/261 [==============================] - 20s 77ms/step - loss: 0.0229 - accuracy: 0.9931 - val_loss: 0.8488 - val_accuracy: 0.8721
# Epoch 4/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.9439 - val_accuracy: 0.8685
# Epoch 5/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0183 - accuracy: 0.9959 - val_loss: 0.8619 - val_accuracy: 0.8455
# Epoch 6/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0245 - accuracy: 0.9914 - val_loss: 0.7531 - val_accuracy: 0.8951
# Epoch 7/50
# 261/261 [==============================] - 19s 72ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.9117 - val_accuracy: 0.8635
# Epoch 8/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0079 - accuracy: 0.9981 - val_loss: 0.7136 - val_accuracy: 0.9159
# Epoch 9/50
# 261/261 [==============================] - 19s 72ms/step - loss: 7.2459e-05 - accuracy: 1.0000 - val_loss: 0.7490 - val_accuracy: 0.9138
# Epoch 10/50
# 261/261 [==============================] - 19s 71ms/step - loss: 4.2456e-05 - accuracy: 1.0000 - val_loss: 0.7762 - val_accuracy: 0.9095
# Epoch 11/50
# 261/261 [==============================] - 19s 71ms/step - loss: 2.8587e-05 - accuracy: 1.0000 - val_loss: 0.7969 - val_accuracy: 0.9095
# Epoch 12/50
# 261/261 [==============================] - 19s 71ms/step - loss: 2.1003e-05 - accuracy: 1.0000 - val_loss: 0.8150 - val_accuracy: 0.9095
# Epoch 13/50
# 261/261 [==============================] - 19s 71ms/step - loss: 1.5737e-05 - accuracy: 1.0000 - val_loss: 0.8294 - val_accuracy: 0.9102
# Epoch 14/50
# 261/261 [==============================] - 19s 71ms/step - loss: 1.2400e-05 - accuracy: 1.0000 - val_loss: 0.8437 - val_accuracy: 0.9102
# Epoch 15/50
# 261/261 [==============================] - 19s 71ms/step - loss: 9.8986e-06 - accuracy: 1.0000 - val_loss: 0.8573 - val_accuracy: 0.9102
# Epoch 16/50
# 261/261 [==============================] - 19s 71ms/step - loss: 8.0453e-06 - accuracy: 1.0000 - val_loss: 0.8692 - val_accuracy: 0.9124
# Epoch 17/50
# 261/261 [==============================] - 19s 72ms/step - loss: 6.6456e-06 - accuracy: 1.0000 - val_loss: 0.8801 - val_accuracy: 0.9124
# Epoch 18/50
# 261/261 [==============================] - 19s 71ms/step - loss: 5.5097e-06 - accuracy: 1.0000 - val_loss: 0.8912 - val_accuracy: 0.9124
# Epoch 19/50
# 261/261 [==============================] - 19s 72ms/step - loss: 4.6209e-06 - accuracy: 1.0000 - val_loss: 0.9019 - val_accuracy: 0.9124
# Epoch 20/50
# 261/261 [==============================] - 19s 72ms/step - loss: 3.9110e-06 - accuracy: 1.0000 - val_loss: 0.9136 - val_accuracy: 0.9124
# Epoch 21/50
# 261/261 [==============================] - 19s 71ms/step - loss: 3.2970e-06 - accuracy: 1.0000 - val_loss: 0.9228 - val_accuracy: 0.9124
# Epoch 22/50
# 261/261 [==============================] - 19s 71ms/step - loss: 2.7895e-06 - accuracy: 1.0000 - val_loss: 0.9327 - val_accuracy: 0.9124
# Epoch 23/50
# 261/261 [==============================] - 19s 71ms/step - loss: 2.3932e-06 - accuracy: 1.0000 - val_loss: 0.9426 - val_accuracy: 0.9124
# Epoch 24/50
# 261/261 [==============================] - 19s 71ms/step - loss: 2.0386e-06 - accuracy: 1.0000 - val_loss: 0.9516 - val_accuracy: 0.9131
# Epoch 25/50
# 261/261 [==============================] - 18s 71ms/step - loss: 1.7496e-06 - accuracy: 1.0000 - val_loss: 0.9609 - val_accuracy: 0.9131
# Epoch 26/50
# 261/261 [==============================] - 18s 70ms/step - loss: 1.5025e-06 - accuracy: 1.0000 - val_loss: 0.9706 - val_accuracy: 0.9131
# Epoch 27/50
# 261/261 [==============================] - 18s 71ms/step - loss: 1.2922e-06 - accuracy: 1.0000 - val_loss: 0.9794 - val_accuracy: 0.9131
# Epoch 28/50
# 261/261 [==============================] - 18s 71ms/step - loss: 1.1071e-06 - accuracy: 1.0000 - val_loss: 0.9885 - val_accuracy: 0.9131
# Epoch 29/50
# 261/261 [==============================] - 18s 70ms/step - loss: 9.5235e-07 - accuracy: 1.0000 - val_loss: 0.9973 - val_accuracy: 0.9131
# Epoch 30/50
# 261/261 [==============================] - 19s 71ms/step - loss: 8.2121e-07 - accuracy: 1.0000 - val_loss: 1.0068 - val_accuracy: 0.9131
# Epoch 31/50
# 261/261 [==============================] - 18s 70ms/step - loss: 7.0988e-07 - accuracy: 1.0000 - val_loss: 1.0153 - val_accuracy: 0.9131
# Epoch 32/50
# 261/261 [==============================] - 18s 70ms/step - loss: 6.1388e-07 - accuracy: 1.0000 - val_loss: 1.0240 - val_accuracy: 0.9131
# Epoch 33/50
# 261/261 [==============================] - 18s 70ms/step - loss: 5.2982e-07 - accuracy: 1.0000 - val_loss: 1.0335 - val_accuracy: 0.9131
# Epoch 34/50
# 261/261 [==============================] - 18s 70ms/step - loss: 4.5405e-07 - accuracy: 1.0000 - val_loss: 1.0413 - val_accuracy: 0.9131
# Epoch 35/50
# 261/261 [==============================] - 18s 70ms/step - loss: 3.9251e-07 - accuracy: 1.0000 - val_loss: 1.0491 - val_accuracy: 0.9131
# Epoch 36/50
# 261/261 [==============================] - 18s 70ms/step - loss: 3.3833e-07 - accuracy: 1.0000 - val_loss: 1.0587 - val_accuracy: 0.9131
# Epoch 37/50
# 261/261 [==============================] - 18s 70ms/step - loss: 2.9203e-07 - accuracy: 1.0000 - val_loss: 1.0667 - val_accuracy: 0.9131
# Epoch 38/50
# 261/261 [==============================] - 18s 69ms/step - loss: 2.5203e-07 - accuracy: 1.0000 - val_loss: 1.0746 - val_accuracy: 0.9131
# Epoch 39/50
# 261/261 [==============================] - 18s 70ms/step - loss: 2.1735e-07 - accuracy: 1.0000 - val_loss: 1.0823 - val_accuracy: 0.9124
# Epoch 40/50
# 261/261 [==============================] - 18s 70ms/step - loss: 1.8658e-07 - accuracy: 1.0000 - val_loss: 1.0903 - val_accuracy: 0.9124
# Epoch 41/50
# 261/261 [==============================] - 18s 70ms/step - loss: 1.6092e-07 - accuracy: 1.0000 - val_loss: 1.0994 - val_accuracy: 0.9124
# Epoch 42/50
# 261/261 [==============================] - 18s 70ms/step - loss: 1.3862e-07 - accuracy: 1.0000 - val_loss: 1.1070 - val_accuracy: 0.9124
# Epoch 43/50
# 261/261 [==============================] - 18s 70ms/step - loss: 1.1907e-07 - accuracy: 1.0000 - val_loss: 1.1147 - val_accuracy: 0.9124
# Epoch 44/50
# 261/261 [==============================] - 18s 71ms/step - loss: 1.0285e-07 - accuracy: 1.0000 - val_loss: 1.1215 - val_accuracy: 0.9124
# Epoch 45/50
# 261/261 [==============================] - 18s 70ms/step - loss: 8.8008e-08 - accuracy: 1.0000 - val_loss: 1.1308 - val_accuracy: 0.9124
# Epoch 46/50
# 261/261 [==============================] - 18s 70ms/step - loss: 7.5790e-08 - accuracy: 1.0000 - val_loss: 1.1388 - val_accuracy: 0.9124
# Epoch 47/50
# 261/261 [==============================] - 18s 70ms/step - loss: 6.4686e-08 - accuracy: 1.0000 - val_loss: 1.1469 - val_accuracy: 0.9124
# Epoch 48/50
# 261/261 [==============================] - 18s 70ms/step - loss: 5.5151e-08 - accuracy: 1.0000 - val_loss: 1.1536 - val_accuracy: 0.9124
# Epoch 49/50
# 261/261 [==============================] - 18s 70ms/step - loss: 4.7244e-08 - accuracy: 1.0000 - val_loss: 1.1614 - val_accuracy: 0.9124
# Epoch 50/50
# 261/261 [==============================] - 18s 70ms/step - loss: 4.1021e-08 - accuracy: 1.0000 - val_loss: 1.1683 - val_accuracy: 0.9124

# %%
plt.plot(model_normal.history['accuracy'])
plt.plot(model_normal.history['loss'])
plt.title('training_trends')
plt.xlabel('epoch')
plt.legend(['accuracy', 'loss'], loc='center')

# %% [markdown]
# %Test

# %%
# Test the model on a testing dataset
# Your Code HERE
test_accuracy = model.evaluate(test_generator)
# Out:
# 87/87 [==============================] - 4s 50ms/step - loss: 1.2526 - accuracy: 0.8714

# %% [markdown]
# ## Part 2.3 - L1 Regularization. Please add L1 regularization setting in your Conv2D layer. Then, train your new model separately, and plot the training process including loss and accuracy. (10 points)

# %%
# please redefine your model with setting the L1 Regularization in the layer of Conv 2D

# Your code HERE
# please redefine your model with setting the L1 Regularization in the layer of Conv 2D

# Your code HERE
model_L1 = Sequential()
model_L1.add(Conv2D(32, (3, 3),input_shape=(224,224,3),kernel_regularizer='l1'))
model_L1.add(Activation('relu'))
model_L1.add(MaxPooling2D(pool_size=(3, 3)))
model_L1.add(Conv2D(32, (3, 3)))
# model_L1.add(regularizers.L1(l1=1e-5))
model_L1.add(Activation('relu'))
model_L1.add(MaxPooling2D(pool_size=(3, 3)))
model_L1.add(Conv2D(64, (3,3)))
model_L1.add(Activation('relu'))
model_L1.add(MaxPooling2D(pool_size=(3, 3)))
# model_L1.add()
model_L1.add(Flatten())
# model.add(Dense(64))
# model.add(Activation('relu'))
model_L1.add(Dense(10))
model_L1.add(Activation('softmax'))

model_L1.compile(optimizer='adam',
              loss= 'categorical_crossentropy',
              metrics=['accuracy'])

#Train the model with training and validation set
model_L1_normal = model_L1.fit(train_generator,steps_per_epoch=len(train_generator),epochs=epochs,validation_data=valid_generator,validation_steps=len(valid_generator))
# Out:
# Epoch 1/50
# 261/261 [==============================] - 31s 73ms/step - loss: 0.9927 - accuracy: 0.7481 - val_loss: 0.6044 - val_accuracy: 0.8815
# Epoch 2/50
# 261/261 [==============================] - 20s 76ms/step - loss: 0.1295 - accuracy: 0.9864 - val_loss: 0.5470 - val_accuracy: 0.8621
# Epoch 3/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0563 - accuracy: 0.9978 - val_loss: 0.5291 - val_accuracy: 0.9023
# Epoch 4/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0345 - accuracy: 0.9995 - val_loss: 0.5574 - val_accuracy: 0.8944
# Epoch 5/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.5383 - val_accuracy: 0.9045
# Epoch 6/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.6031 - val_accuracy: 0.8807
# Epoch 7/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0353 - accuracy: 0.9933 - val_loss: 0.8752 - val_accuracy: 0.8736
# Epoch 8/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0345 - accuracy: 0.9943 - val_loss: 0.6678 - val_accuracy: 0.8815
# Epoch 9/50
# 261/261 [==============================] - 19s 72ms/step - loss: 0.0126 - accuracy: 0.9993 - val_loss: 0.5904 - val_accuracy: 0.8958
# Epoch 10/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.5719 - val_accuracy: 0.8980
# Epoch 11/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.5601 - val_accuracy: 0.8980
# Epoch 12/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.5629 - val_accuracy: 0.9001
# Epoch 13/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.5506 - val_accuracy: 0.9009
# Epoch 14/50
# 261/261 [==============================] - 19s 72ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.5583 - val_accuracy: 0.8944
# Epoch 15/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5723 - val_accuracy: 0.8951
# Epoch 16/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.5602 - val_accuracy: 0.8951
# Epoch 17/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5719 - val_accuracy: 0.8958
# Epoch 18/50
# 261/261 [==============================] - 19s 72ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.5813 - val_accuracy: 0.9059
# Epoch 19/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.5780 - val_accuracy: 0.9016
# Epoch 20/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.5965 - val_accuracy: 0.9001
# Epoch 21/50
# 261/261 [==============================] - 19s 72ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.6021 - val_accuracy: 0.8973
# Epoch 22/50
# 261/261 [==============================] - 19s 72ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.6060 - val_accuracy: 0.9037
# Epoch 23/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.5989 - val_accuracy: 0.9088
# Epoch 24/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.6243 - val_accuracy: 0.9080
# Epoch 25/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.6110 - val_accuracy: 0.9066
# Epoch 26/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.6390 - val_accuracy: 0.9016
# Epoch 27/50
# 261/261 [==============================] - 19s 75ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.6545 - val_accuracy: 0.9073
# Epoch 28/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.7900 - val_accuracy: 0.8786
# Epoch 29/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0874 - accuracy: 0.9794 - val_loss: 1.0895 - val_accuracy: 0.8736
# Epoch 30/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.0390 - val_accuracy: 0.8851
# Epoch 31/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.9624 - val_accuracy: 0.8807
# Epoch 32/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.8830 - val_accuracy: 0.8772
# Epoch 33/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.8272 - val_accuracy: 0.8800
# Epoch 34/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.7941 - val_accuracy: 0.8865
# Epoch 35/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.7819 - val_accuracy: 0.8822
# Epoch 36/50
# 261/261 [==============================] - 19s 72ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.7675 - val_accuracy: 0.8793
# Epoch 37/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.7561 - val_accuracy: 0.8822
# Epoch 38/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.7422 - val_accuracy: 0.8829
# Epoch 39/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.7391 - val_accuracy: 0.8815
# Epoch 40/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.7285 - val_accuracy: 0.8865
# Epoch 41/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.7111 - val_accuracy: 0.8865
# Epoch 42/50
# 261/261 [==============================] - 19s 72ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.7108 - val_accuracy: 0.8886
# Epoch 43/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.6977 - val_accuracy: 0.8922
# Epoch 44/50
# 261/261 [==============================] - 19s 72ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6953 - val_accuracy: 0.8915
# Epoch 45/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6870 - val_accuracy: 0.8973
# Epoch 46/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.6875 - val_accuracy: 0.8951
# Epoch 47/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6881 - val_accuracy: 0.8987
# Epoch 48/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6859 - val_accuracy: 0.8915
# Epoch 49/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6873 - val_accuracy: 0.8966
# Epoch 50/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.7037 - val_accuracy: 0.8930

# %%
plt.plot(model_L1_normal.history['accuracy'])
plt.plot(model_L1_normal.history['loss'])
plt.title('training_trends')
plt.xlabel('epoch')
plt.legend(['accuracy', 'loss'], loc='center')
plt.show()

# %%
test_accuracy_L1 = model_L1.evaluate(test_generator)
# Out:
# 87/87 [==============================] - 4s 50ms/step - loss: 0.7042 - accuracy: 0.8527

# %% [markdown]
# ## Part 2.4 - L2 Regularization. Please add L2 regularization setting in your Conv2D layer. Then, train your new model separately, and plot the training process including loss and accuracy. (10 points)

# %%
#please redefine your model and set the L2 Regularization in the layer of Conv 2D

# Your code HERE
model_L2 = Sequential()
model_L2.add(Conv2D(32, (3, 3),input_shape=(224,224,3),kernel_regularizer='l1_l2'))
model_L2.add(Activation('relu'))
model_L2.add(MaxPooling2D(pool_size=(3, 3)))
model_L2.add(Conv2D(32, (3, 3)))
# model_L1.add(regularizers.L1(l1=1e-5))
model_L2.add(Activation('relu'))
model_L2.add(MaxPooling2D(pool_size=(3, 3)))
model_L2.add(Conv2D(64, (3,3)))
model_L2.add(Activation('relu'))
model_L2.add(MaxPooling2D(pool_size=(3, 3)))
# model_L1.add()
model_L2.add(Flatten())
# model.add(Dense(64))
# model.add(Activation('relu'))
model_L2.add(Dense(10))
model_L2.add(Activation('softmax'))

model_L2.compile(optimizer='adam',
              loss= 'categorical_crossentropy',
              metrics=['accuracy'])

#Train the model with training and validation set
model_L2_normal = model_L2.fit(train_generator,steps_per_epoch=len(train_generator),epochs=epochs,validation_data=valid_generator,validation_steps=len(valid_generator))
# Out:
# Epoch 1/50
# 261/261 [==============================] - 21s 76ms/step - loss: 0.9674 - accuracy: 0.7514 - val_loss: 0.7188 - val_accuracy: 0.8233
# Epoch 2/50
# 261/261 [==============================] - 20s 76ms/step - loss: 0.1312 - accuracy: 0.9864 - val_loss: 0.5321 - val_accuracy: 0.8865
# Epoch 3/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0614 - accuracy: 0.9974 - val_loss: 0.4969 - val_accuracy: 0.8886
# Epoch 4/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0417 - accuracy: 0.9981 - val_loss: 0.6178 - val_accuracy: 0.8822
# Epoch 5/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0309 - accuracy: 0.9986 - val_loss: 0.4928 - val_accuracy: 0.9095
# Epoch 6/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.5263 - val_accuracy: 0.9095
# Epoch 7/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.5331 - val_accuracy: 0.9045
# Epoch 8/50
# 261/261 [==============================] - 19s 75ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.5609 - val_accuracy: 0.9066
# Epoch 9/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.6306 - val_accuracy: 0.9052
# Epoch 10/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.5888 - val_accuracy: 0.9080
# Epoch 11/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.5984 - val_accuracy: 0.9059
# Epoch 12/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.7148 - val_accuracy: 0.8714
# Epoch 13/50
# 261/261 [==============================] - 19s 74ms/step - loss: 0.1013 - accuracy: 0.9727 - val_loss: 0.6904 - val_accuracy: 0.8879
# Epoch 14/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.5702 - val_accuracy: 0.9102
# Epoch 15/50
# 261/261 [==============================] - 19s 72ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.5576 - val_accuracy: 0.9066
# Epoch 16/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5559 - val_accuracy: 0.9059
# Epoch 17/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5633 - val_accuracy: 0.9016
# Epoch 18/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.5699 - val_accuracy: 0.9059
# Epoch 19/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.5706 - val_accuracy: 0.9037
# Epoch 20/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.5635 - val_accuracy: 0.9023
# Epoch 21/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.5709 - val_accuracy: 0.9016
# Epoch 22/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.5685 - val_accuracy: 0.9045
# Epoch 23/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.5676 - val_accuracy: 0.9023
# Epoch 24/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.5711 - val_accuracy: 0.9009
# Epoch 25/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.5825 - val_accuracy: 0.9045
# Epoch 26/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.6034 - val_accuracy: 0.9045
# Epoch 27/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5798 - val_accuracy: 0.9030
# Epoch 28/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.5901 - val_accuracy: 0.9016
# Epoch 29/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.6019 - val_accuracy: 0.9016
# Epoch 30/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.6153 - val_accuracy: 0.9102
# Epoch 31/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.6089 - val_accuracy: 0.9023
# Epoch 32/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.6269 - val_accuracy: 0.9102
# Epoch 33/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.6012 - val_accuracy: 0.8994
# Epoch 34/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.6182 - val_accuracy: 0.9023
# Epoch 35/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.6318 - val_accuracy: 0.9088
# Epoch 36/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.1055 - accuracy: 0.9782 - val_loss: 0.8967 - val_accuracy: 0.8829
# Epoch 37/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0146 - accuracy: 0.9988 - val_loss: 0.8854 - val_accuracy: 0.8822
# Epoch 38/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.8877 - val_accuracy: 0.8915
# Epoch 39/50
# 261/261 [==============================] - 18s 69ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.8447 - val_accuracy: 0.8994
# Epoch 40/50
# 261/261 [==============================] - 18s 69ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.7922 - val_accuracy: 0.8966
# Epoch 41/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.7645 - val_accuracy: 0.8966
# Epoch 42/50
# 261/261 [==============================] - 18s 71ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.7526 - val_accuracy: 0.8901
# Epoch 43/50
# 261/261 [==============================] - 19s 71ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.7456 - val_accuracy: 0.8915
# Epoch 44/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.7355 - val_accuracy: 0.8973
# Epoch 45/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.7346 - val_accuracy: 0.9037
# Epoch 46/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.7332 - val_accuracy: 0.9016
# Epoch 47/50
# 261/261 [==============================] - 18s 69ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.7277 - val_accuracy: 0.9023
# Epoch 48/50
# 261/261 [==============================] - 19s 74ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.7263 - val_accuracy: 0.9095
# Epoch 49/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.7272 - val_accuracy: 0.9009
# Epoch 50/50
# 261/261 [==============================] - 18s 70ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.7167 - val_accuracy: 0.9080

# %%
plt.plot(model_L2_normal.history['accuracy'])
plt.plot(model_L2_normal.history['loss'])
plt.title('training_trends')
plt.xlabel('epoch')
plt.legend(['accuracy', 'loss'], loc='center')
plt.show()

# %%
test_accuracy_l2 = model_L2.evaluate(test_generator)
# Out:
# 87/87 [==============================] - 5s 51ms/step - loss: 0.6764 - accuracy: 0.8664

# %% [markdown]
# ## Part3 - ** only for 574 students **.
# 1. Fine tune the well pre-trained model, Resnet 50, with different freeze layers.
# First,  load pre-trained resnet 50 from library.
# Second, Fine-tune the model to fit our project, 10-classes.
# Third,  freeze different layers, plot different training process with different frozen layers (at least three different layers).

# %%
# load pre-trained resnet 50 from libarary
# your Code HERE


# Fine-tune the model to fit our project  
# your Code HERE


# define the freeze layers 
# your Code HERE


# Please compile the new model
#model.compile()


#Train the model with training and validation set
#model.fit()
